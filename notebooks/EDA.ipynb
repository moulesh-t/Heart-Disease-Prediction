# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print("Data Types: ")
print(df.info())
# Out:
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
print("Unique Values in the target column: ")
print(df['target'].value_counts())
# Out:
# Unique Values in the target column:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
print("Unique Values per column: ")
print(df.nunique())
# Out:
# Unique Values per column:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
plt.figure(figsize=(8,6))
df['target'].value_counts().plot(kind='bar')
plt.title('Target Distribution')
plt.savefig('../plots/target-distribution.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# Correlation Plot
corr = df.corr()
plt.figure(figsize=(14,6))
sns.heatmap(corr, annot=True, cmap='plasma')
plt.title('Correlation Heatmap')
plt.savefig('../plots/correlation.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# Pairplots of various features
sns.pairplot(df, hue='target', palette='plasma', diag_kind='kde')
plt.figure(figsize=(6,4))
plt.suptitle('Pair Plot Colored by Target', y=1.02)
plt.savefig('../plots/pairplot.png', dpi=600, )
plt.savefig('../plots/pairplot.png', dpi=600, )
plt.savefig('../plots/pairplot.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df.boxplot()
plt.title('Box Plots for Outlier Detection')
plt.xticks(rotation=45)
plt.savefig('../plots/boxplots_outliers.png', dpi=300, bbox_inches='tight')
plt.show()
